# %%
import matplotlib
#%matplotlib notebook
# %matplotlib inline
matplotlib.style.use('ggplot')

import matplotlib.pyplot as plt
# Out:
# /Users/jgrout6/anaconda/lib/python3.5/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %% [markdown]
# - Exploring Data With Pandas [5 min]
#  - Basic read data
#  - Basic show data
#  - Pivot/Unstack/etc.
#  - GroupBy/Summarize

# %% [markdown]
# # Pandas - http://pandas.pydata.org/
#
# * Short history
# * Brief list of capabilities
#   * A pandas Dataframe is a table of data with labeled columns and indices.
#   *

# %%
import pandas as pd

# %%
df = pd.read_csv('./iris.data')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df['Name'] = df['Name'].str[5:]

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth    Name
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %% [markdown]
# # Group by Iris type

# %%
df.groupby('Name').mean()
# Out:
#             SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# setosa            5.006       3.418        1.464       0.244
# versicolor        5.936       2.770        4.260       1.326
# virginica         6.588       2.974        5.552       2.026

# %% [markdown]
# # Summarize data
# * Calculate stats on each iris type

# %%
g = df.groupby('Name')

# %%
df.plot(kind='scatter', x='SepalLength', y='SepalWidth')
# Out:
# <img src="data:image/png;base64,...">

# %%
from pandas.tools.plotting import radviz
plt.figure(figsize=(8,6))
radviz(df, 'Name')

# %%
import seaborn as sns
sns.set()

# %%
sns.pairplot(df, diag_kind="kde", hue="Name")
